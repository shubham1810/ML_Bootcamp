# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import scipy as sp
import scipy.stats as stat

# %%
x = np.linspace(-1, 2, 100)
z = np.logspace(-1, 2, 100)
y = np.random.random(100)

plt.scatter(x, y)

# %%
x = np.linspace

# %%
mu = [0.0]
cov = [[1]] 

a = np.random.multivariate_normal(mu, cov, 50000)

b = np.cumsum(a)

# %%
plt.figure(0)
plt.plot(np.histogram(a, bins=200)[0])

h = sorted(a)

f = stat.norm.pdf(h, np.mean(h), np.std(h))
plt.figure(1)
plt.plot(h, f)

# %%
np.
